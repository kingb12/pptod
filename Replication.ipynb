# %% [markdown]
# <a href="https://colab.research.google.com/github/kingb12/pptod/blob/main/Replication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/kingb12/pptod
# Out:
# fatal: destination path 'pptod' already exists and is not an empty directory.

# %%
# !cd /content/pptod/
# !pip install -r requirements.txt

# %%
cd /content/pptod/data/pre-training_corpora/
# Out:
# /content/pptod/data/pre-training_corpora

# %%
# download the raw ToD-BERT data
# !bash download_raw_data.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-d645d56d23-20130324_232416/log.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-d645d56d23-20130324_232416/label.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-d225fad9df-20130328_201024/log.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-d225fad9df-20130328_201024/label.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-aaa44b4121-20130327_170719/log.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-aaa44b4121-20130327_170719/label.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-e0035cc31b-20130323_211206/log.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-e0035cc31b-20130323_211206/label.json
#   inflating: dialog_datasets/dstc2/data/Mar13_S0A1/voip-72e50baa85-20130326_051956/log.json
# ...

# %%
# process data
# !bash process_pre-training_data.sh
# !bash post-processing_pre-training_data.sh
# Out:
# Processing CamRes676 Dataset...
# 676 676
# Processing CamRes676 Dataset Finished!
# Processing Frame Dataset...
# 1367 1369
# Processing Frame Dataset Finished!
# Processing KVRET Dataset...
# 2422 2425
# 302 302
# 304 304
# Processing KVRET Dataset Finished!
# Processing MetalWOZ Dataset...
# 37884
# 47
# 34384 3500
# Processing MetalWOZ Dataset Finished!
# Processing MSE2E Dataset...
# 3094 3094
# 2889 2890
# 4089 4103
# Processing MSE2E Dataset Finished!
# Processing Schema-Guided Dataset...
# 16142
# 16142
# 2482
# 2482
# Processing Schema-Guided Dataset Finished!
# Processing TaskMaster Dataset...
# 7708 7708
# 5440 5507
# 13148
# Processing TaskMaster Dataset Finished!
# Processing WOZ Dataset...
# 600 600
# 200 200
# 400 400
# Processing WOZ Dataset Finished!
# Processing Intent Classification Datasets...
# 40727
# Processing Intent Classification Datasets Finished!
# Saving Tokenizer...
# Traceback (most recent call last):
#   File "build_tokenizer.py", line 14, in <module>
# ...
